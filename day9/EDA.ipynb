# %%
# %pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (2.4.6)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\Users\aashi\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# load dataset

# %%
iris=sns.load_dataset('iris')

# %% [markdown]
# display first 5 rows

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# import iris dataset

# %%
from sklearn.datasets import load_iris
iris_data=load_iris()

# %%
type(iris_data)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(iris_data.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
print('feature names :',iris_data['feature_names'])
print('target names :',iris_data['target_names'])
print('data :',iris_data['data'])
# Out:
# feature names : ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# target names : ['setosa' 'versicolor' 'virginica']
# data : [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.2]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.6 1.4 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
#  [4.6 3.2 1.4 0.2]
#  [5.3 3.7 1.5 0.2]
#  [5.  3.3 1.4 0.2]
#  [7.  3.2 4.7 1.4]
#  [6.4 3.2 4.5 1.5]
#  [6.9 3.1 4.9 1.5]
#  [5.5 2.3 4.  1.3]
#  [6.5 2.8 4.6 1.5]
#  [5.7 2.8 4.5 1.3]
#  [6.3 3.3 4.7 1.6]
#  [4.9 2.4 3.3 1. ]
#  [6.6 2.9 4.6 1.3]
#  [5.2 2.7 3.9 1.4]
#  [5.  2.  3.5 1. ]
#  [5.9 3.  4.2 1.5]
#  [6.  2.2 4.  1. ]
#  [6.1 2.9 4.7 1.4]
#  [5.6 2.9 3.6 1.3]
#  [6.7 3.1 4.4 1.4]
#  [5.6 3.  4.5 1.5]
#  [5.8 2.7 4.1 1. ]
#  [6.2 2.2 4.5 1.5]
#  [5.6 2.5 3.9 1.1]
#  [5.9 3.2 4.8 1.8]
#  [6.1 2.8 4.  1.3]
#  [6.3 2.5 4.9 1.5]
#  [6.1 2.8 4.7 1.2]
#  [6.4 2.9 4.3 1.3]
#  [6.6 3.  4.4 1.4]
#  [6.8 2.8 4.8 1.4]
#  [6.7 3.  5.  1.7]
#  [6.  2.9 4.5 1.5]
#  [5.7 2.6 3.5 1. ]
#  [5.5 2.4 3.8 1.1]
#  [5.5 2.4 3.7 1. ]
#  [5.8 2.7 3.9 1.2]
#  [6.  2.7 5.1 1.6]
#  [5.4 3.  4.5 1.5]
#  [6.  3.4 4.5 1.6]
#  [6.7 3.1 4.7 1.5]
#  [6.3 2.3 4.4 1.3]
#  [5.6 3.  4.1 1.3]
#  [5.5 2.5 4.  1.3]
#  [5.5 2.6 4.4 1.2]
#  [6.1 3.  4.6 1.4]
#  [5.8 2.6 4.  1.2]
#  [5.  2.3 3.3 1. ]
#  [5.6 2.7 4.2 1.3]
#  [5.7 3.  4.2 1.2]
#  [5.7 2.9 4.2 1.3]
#  [6.2 2.9 4.3 1.3]
#  [5.1 2.5 3.  1.1]
#  [5.7 2.8 4.1 1.3]
#  [6.3 3.3 6.  2.5]
#  [5.8 2.7 5.1 1.9]
#  [7.1 3.  5.9 2.1]
#  [6.3 2.9 5.6 1.8]
#  [6.5 3.  5.8 2.2]
#  [7.6 3.  6.6 2.1]
#  [4.9 2.5 4.5 1.7]
#  [7.3 2.9 6.3 1.8]
#  [6.7 2.5 5.8 1.8]
#  [7.2 3.6 6.1 2.5]
#  [6.5 3.2 5.1 2. ]
#  [6.4 2.7 5.3 1.9]
#  [6.8 3.  5.5 2.1]
#  [5.7 2.5 5.  2. ]
#  [5.8 2.8 5.1 2.4]
#  [6.4 3.2 5.3 2.3]
#  [6.5 3.  5.5 1.8]
#  [7.7 3.8 6.7 2.2]
#  [7.7 2.6 6.9 2.3]
#  [6.  2.2 5.  1.5]
#  [6.9 3.2 5.7 2.3]
#  [5.6 2.8 4.9 2. ]
#  [7.7 2.8 6.7 2. ]
#  [6.3 2.7 4.9 1.8]
#  [6.7 3.3 5.7 2.1]
#  [7.2 3.2 6.  1.8]
#  [6.2 2.8 4.8 1.8]
#  [6.1 3.  4.9 1.8]
#  [6.4 2.8 5.6 2.1]
#  [7.2 3.  5.8 1.6]
#  [7.4 2.8 6.1 1.9]
#  [7.9 3.8 6.4 2. ]
#  [6.4 2.8 5.6 2.2]
#  [6.3 2.8 5.1 1.5]
#  [6.1 2.6 5.6 1.4]
#  [7.7 3.  6.1 2.3]
#  [6.3 3.4 5.6 2.4]
#  [6.4 3.1 5.5 1.8]
#  [6.  3.  4.8 1.8]
#  [6.9 3.1 5.4 2.1]
#  [6.7 3.1 5.6 2.4]
#  [6.9 3.1 5.1 2.3]
#  [5.8 2.7 5.1 1.9]
#  [6.8 3.2 5.9 2.3]
#  [6.7 3.3 5.7 2.5]
#  [6.7 3.  5.2 2.3]
#  [6.3 2.5 5.  1.9]
#  [6.5 3.  5.2 2. ]
#  [6.2 3.4 5.4 2.3]
#  [5.9 3.  5.1 1.8]]

# %%
iris_df=pd.DataFrame(data=iris_data.data,columns=iris_data.feature_names)
print(iris_df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
iris_df['Iris type']=iris_data['target']
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Iris type
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# from .csv file

# %%
from PIL import Image
img=Image.open(r"C:\Users\aashi\OneDrive\Desktop\vs\internship\day9\data\iris.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x960>

# %%
df=pd.read_csv(r"C:\Users\aashi\OneDrive\Desktop\vs\internship\day9\data\iris.csv")
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# Basic  dataset exploration

# %%
#dataset shape
print(f'Dataset shape:{iris.shape}')
iris.info()
# Out:
# Dataset shape:(150, 5)
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Missing values/Null values

# %%
#missing values
print(f'Missing values:\n{iris.isnull().sum()}')
# Out:
# Missing values:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# Duplicated values

# %%
dup=iris.duplicated().sum()
print(f'number of duplicated row are {dup}')
# Out:
# number of duplicated row are 1

# %% [markdown]
# Value count

# %%
print(iris['species'].value_counts())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# categorical encoding

# %%
#categorical encoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
iris['species']=le.fit_transform(iris['species'])
unique_species=iris['species'].unique()
print('Encoded species values',unique_species)
iris_df.head()
# Out:
# Encoded species values [0 1 2]
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Iris type
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
print('\n species distribution:')
print(iris['species'].value_counts())
# Out:
#  species distribution:
# species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %% [markdown]
# univariate Analysis

# %%
#distribution of numerical features
fig,axes=plt.subplots(nrows=2,ncols=2,figsize=(15,10))
sns.histplot(iris['sepal_length'],kde=True,ax=axes[0,0],color='green')
axes[0,0].set_title('sepal length distribution')
sns.histplot(iris['sepal_width'],kde=True,ax=axes[0,1],color='skyblue')
axes[0,1].set_title('sepal width distribution')
sns.histplot(iris['petal_length'],kde=True,ax=axes[1,0],color='orange')
axes[1,0].set_title('petal length distribution')
sns.histplot(iris['petal_width'],kde=True,ax=axes[1,1],color='red')
axes[1,1].set_title('petal width distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# boxplot for numerical features

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=iris.drop('species',axis=1))
plt.title('Boxplot of Numerical Features')
plt.ylabel('centimeters')
plt.show()

# %%
#default theme
sns.set(context='notebook', style='darkgrid', palette='colorblind', font='sans-serif', font_scale=1,rc=None)
plt.rcParams['figure.figsize'] =[8,8]
plt.rcParams.update({'font.size': 15})
plt.rcParams['font.family'] = 'sans-serif'
sns.set_style('darkgrid')

# %%
sns.countplot(x='species',data=iris)
plt.title('Species Distribution')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

# %%
iris['species'].value_counts().plot.pie(explode=[0.1,0.1,0.1],autopct='%1.1f%%',shadow=True,figsize=(10,8))
plt.title('Species Distribution')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Distribution of numerical variables

# %%
iris.hist(edgecolor='black',figsize=(12,12))
plt.suptitle('Histogram of Numerical Features')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.suptitle('Distribution of iris flower measurement',fontsize=14)

plt.subplot(2,2,1)
plt.hist(iris['sepal_length'],color='green',edgecolor='black')
plt.title('sepal_length distribution')

plt.subplot(2,2,2)
plt.hist(iris['sepal_width'],color='blue',edgecolor='black')
plt.title('sepal_width distribution')

plt.subplot(2,2,3)
plt.hist(iris['petal_length'],color='orange',edgecolor='black')
plt.title('petal_length distribution')

plt.subplot(2,2,4)
plt.hist(iris['petal_width'],color='red',edgecolor='black')
plt.title('petal_width distribution')

plt.tight_layout()
plt.show()

# %%
sns.boxplot(x='species',y='petal_length',data=iris)
plt.title('Boxplot of Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('Petal Length')
plt.show()

# %%
ax=sns.boxplot(x='species',y='petal_width',data=iris)
ax=sns.stripplot(x='species',y='petal_width',data=iris,jitter=True,edgecolor='gray')
plt.title('Boxplot and Striplot of Petal Width by Species')
plt.xlabel('Species')
plt.ylabel('Petal Width')
plt.show()
# Out:
# C:\Users\aashi\AppData\Local\Temp\ipykernel_1248\2441741413.py:2: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax=sns.stripplot(x='species',y='petal_width',data=iris,jitter=True,edgecolor='gray')

# %% [markdown]
# Bivariate analysis

# %%
plt.figure(figsize=(8,6))
species=iris['species'].unique()
colors=['red','green','blue']
for i in range(len(species)):
  x=iris[iris['species']==species[i]]
  plt.scatter(x['sepal_length'],x['sepal_width'],c=colors[i],label=species[i])
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.title('sepal_length vs sepal_width')
plt.legend()
plt.show()

# %%
iris.plot(kind='scatter',x='sepal_length',y='sepal_width')
plt.show()

# %%
sns.pairplot(iris,hue='species')
plt.show()

# %%
sns.pairplot(iris,hue='sepal_width')
plt.show()

# %%
sns.pairplot(iris,hue='species',palette='viridis',height=2.5)
plt.suptitle('Pairwise Relationship between species',y=1.02)
plt.show()

# %% [markdown]
# correlation heatmap

# %%
corr=iris.drop('species',axis=1).corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr,annot=True,cmap='coolwarm',center=0,fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width   species
# sepal_length      1.000000    -0.117570      0.871754     0.817941  0.782561
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126 -0.426658
# petal_length      0.871754    -0.428440      1.000000     0.962865  0.949035
# petal_width       0.817941    -0.366126      0.962865     1.000000  0.956547
# species           0.782561    -0.426658      0.949035     0.956547  1.000000

# %%
iris.iloc[:,:-1].corr().style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_a470d_row0_col0, #T_a470d_row1_col1, #T_a470d_row2_col2, #T_a470d_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a470d_row0_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_a470d_row0_col2 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_a470d_row0_col3 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_a470d_row1_col0, #T_a470d_row1_col2, #T_a470d_row1_col3, #T_a470d_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a470d_row2_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_a470d_row2_col3, #T_a470d_row3_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_a470d_row3_col0 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_a470d_row3_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a470d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a470d_level0_col0" class="col_heading level0 col0" >sepal_length</th>
#       <th id="T_a470d_level0_col1" class="col_heading level0 col1" >sepal_width</th>
#       <th id="T_a470d_level0_col2" class="col_heading level0 col2" >petal_length</th>
#       <th id="T_a470d_level0_col3" class="col_heading level0 col3" >petal_width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a470d_level0_row0" class="row_heading level0 row0" >sepal_length</th>
#       <td id="T_a470d_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_a470d_row0_col1" class="data row0 col1" >-0.12</td>
#       <td id="T_a470d_row0_col2" class="data row0 col2" >0.87</td>
#       <td id="T_a470d_row0_col3" class="data row0 col3" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_a470d_level0_row1" class="row_heading level0 row1" >sepal_width</th>
#       <td id="T_a470d_row1_col0" class="data row1 col0" >-0.12</td>
#       <td id="T_a470d_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_a470d_row1_col2" class="data row1 col2" >-0.43</td>
#       <td id="T_a470d_row1_col3" class="data row1 col3" >-0.37</td>
#     </tr>
#     <tr>
#       <th id="T_a470d_level0_row2" class="row_heading level0 row2" >petal_length</th>
#       <td id="T_a470d_row2_col0" class="data row2 col0" >0.87</td>
#       <td id="T_a470d_row2_col1" class="data row2 col1" >-0.43</td>
#       <td id="T_a470d_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_a470d_row2_col3" class="data row2 col3" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_a470d_level0_row3" class="row_heading level0 row3" >petal_width</th>
#       <td id="T_a470d_row3_col0" class="data row3 col0" >0.82</td>
#       <td id="T_a470d_row3_col1" class="data row3 col1" >-0.37</td>
#       <td id="T_a470d_row3_col2" class="data row3 col2" >0.96</td>
#       <td id="T_a470d_row3_col3" class="data row3 col3" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# multivariate analysis

# %%
fig,axes=plt.subplots(nrows=2,ncols=2,figsize=(15,10))

sns.boxplot(x='species',y='sepal_length',data=iris,ax=axes[0,0],palette='Set2')
axes[0,0].set_title('sepal_length by species')

sns.boxplot(x='species',y='sepal_width',data=iris,ax=axes[0,1],palette='Set2')
axes[0,1].set_title('sepal_width by species')

sns.boxplot(x='species',y='petal_length',data=iris,ax=axes[1,0],palette='Set2')
axes[1,0].set_title('petal_length by species')

sns.boxplot(x='species',y='petal_width',data=iris,ax=axes[1,1],palette='Set2')
axes[1,1].set_title('petal_width by species')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\aashi\AppData\Local\Temp\ipykernel_1248\1096548800.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species',y='sepal_length',data=iris,ax=axes[0,0],palette='Set2')
# C:\Users\aashi\AppData\Local\Temp\ipykernel_1248\1096548800.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species',y='sepal_width',data=iris,ax=axes[0,1],palette='Set2')
# C:\Users\aashi\AppData\Local\Temp\ipykernel_1248\1096548800.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species',y='petal_length',data=iris,ax=axes[1,0],palette='Set2')
# C:\Users\aashi\AppData\Local\Temp\ipykernel_1248\1096548800.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species',y='petal_width',data=iris,ax=axes[1,1],palette='Set2')

# %% [markdown]
# Violin plots

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='species',y='petal_length',data=iris,inner='quartile',palette='pastel')
plt.title('Violin Plot of Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('Petal Length')
plt.show()
# Out:
# C:\Users\aashi\AppData\Local\Temp\ipykernel_1248\1107581532.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='species',y='petal_length',data=iris,inner='quartile',palette='pastel')

# %% [markdown]
# Advanced visualization

# %% [markdown]
# Andrews curves

# %%
from pandas.plotting import andrews_curves
plt.figure(figsize=(10,6))
andrews_curves(iris,'species',colormap='viridis')
plt.title('Andrews Curves for Iris Dataset')
plt.show()

# %% [markdown]
# Parallel coordination

# %%
from pandas.plotting import parallel_coordinates
plt.figure(figsize=(10,6))
parallel_coordinates(iris,'species',colormap='viridis')
plt.title('Parallel Coordinates Plot for Iris Dataset')
plt.show()
